# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('fmcg_sales_marketing_profitability_2023_2025.csv')
data
# Out:
#                Order_ID  Order_Date  Year Quarter  Month Month_Name  \
# 0      FMCG-2025-000001  2025-09-26  2025      Q3      9  September
# 1      FMCG-2024-000002  2024-10-09  2024      Q4     10    October
# 2      FMCG-2024-000003  2024-07-06  2024      Q3      7       July
# 3      FMCG-2024-000004  2024-05-25  2024      Q2      5        May
# 4      FMCG-2023-000005  2023-08-10  2023      Q3      8     August
# ...                 ...         ...   ...     ...    ...        ...
# 18235  FMCG-2023-018236  2023-01-19  2023      Q1      1    January
# 18236  FMCG-2023-018237  2023-06-22  2023      Q2      6       June
# 18237  FMCG-2025-018238  2025-10-30  2025      Q4     10    October
# 18238  FMCG-2023-018239  2023-12-25  2023      Q4     12   December
# 18239  FMCG-2024-018240  2024-06-20  2024      Q2      6       June
#
#               Region    Country            City   Sales_Person  ...  \
# 0            Oceania  Australia           Perth     Ethan Cole  ...
# 1               Asia      India          Mumbai     Meera Nair  ...
# 2      North America        USA     Los Angeles    Nina Booker  ...
# 3             Europe     France           Paris    Oliver Kent  ...
# 4             Europe     France            Lyon  Lucas Bennett  ...
# ...              ...        ...             ...            ...  ...
# 18235           Asia  Indonesia         Jakarta    Anika Verma  ...
# 18236         Europe      Spain          Madrid   Elena Dupont  ...
# 18237         Europe     France           Paris  Marco Bellini  ...
# 18238  South America     Brazil  Rio de Janeiro  Lucia Herrera  ...
# 18239         Europe    Germany         Hamburg  Marco Bellini  ...
#
#       Units_Sold Unit_Price_USD Discount_Pct Gross_Sales_USD  \
# 0             73           8.47         8.94          618.31
# 1             99           2.89         9.86          286.11
# 2            361           5.96        15.32         2151.56
# 3            603           3.80        18.00         2291.40
# 4            113           3.18        12.46          359.34
# ...          ...            ...          ...             ...
# 18235         39           7.87        13.68          306.93
# 18236         53           6.06        13.93          321.18
# 18237        143           3.43        13.21          490.49
# 18238        237           6.02        13.82         1426.74
# 18239         83           3.42         6.07          283.86
#
#       Marketing_Spend_USD COGS_USD Logistics_Cost_USD  Net_Revenue_USD  \
# 0                   66.05   314.09              43.03           563.03
# 1                   35.26   123.79              23.89           257.90
# 2                  171.46  1011.60             107.02          1821.94
# 3                  118.39  1133.66              85.20          1878.95
# 4                   34.82   157.70              23.02           314.57
# ...                   ...      ...                ...              ...
# 18235               41.32   149.17              31.24           264.94
# 18236               35.42   155.27              21.25           276.44
# 18237               72.35   314.69              36.50           425.70
# 18238              124.61   713.18              92.59          1229.56
# 18239               43.66   184.79              32.67           266.63
#
#        Profit_USD  Profit_Margin_Pct
# 0          139.86              24.84
# 1           74.96              29.07
# 2          531.86              29.19
# 3          541.70              28.83
# 4           99.03              31.48
# ...           ...                ...
# 18235       43.21              16.31
# 18236       64.50              23.33
# 18237        2.16               0.51
# 18238      299.18              24.33
# 18239        5.51               2.07
#
# [18240 rows x 27 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18240 entries, 0 to 18239
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order_ID             18240 non-null  object
#  1   Order_Date           18240 non-null  object
#  2   Year                 18240 non-null  int64
#  3   Quarter              18240 non-null  object
#  4   Month                18240 non-null  int64
#  5   Month_Name           18240 non-null  object
#  6   Region               18240 non-null  object
#  7   Country              18240 non-null  object
#  8   City                 18240 non-null  object
#  9   Sales_Person         18240 non-null  object
#  10  Customer_Type        18240 non-null  object
#  11  Sales_Channel        18240 non-null  object
#  12  Promotion_Type       18240 non-null  object
#  13  Product_Category     18240 non-null  object
#  14  Brand                18240 non-null  object
#  15  Product_Name         18240 non-null  object
#  16  SKU                  18240 non-null  object
#  17  Units_Sold           18240 non-null  int64
#  18  Unit_Price_USD       18240 non-null  float64
#  19  Discount_Pct         18240 non-null  float64
#  20  Gross_Sales_USD      18240 non-null  float64
#  21  Marketing_Spend_USD  18240 non-null  float64
#  22  COGS_USD             18240 non-null  float64
#  23  Logistics_Cost_USD   18240 non-null  float64
#  24  Net_Revenue_USD      18240 non-null  float64
#  25  Profit_USD           18240 non-null  float64
#  26  Profit_Margin_Pct    18240 non-null  float64
# dtypes: float64(9), int64(3), object(15)
# memory usage: 3.8+ MB

# %%
data.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Year', 'Quarter', 'Month', 'Month_Name',
#        'Region', 'Country', 'City', 'Sales_Person', 'Customer_Type',
#        'Sales_Channel', 'Promotion_Type', 'Product_Category', 'Brand',
#        'Product_Name', 'SKU', 'Units_Sold', 'Unit_Price_USD', 'Discount_Pct',
#        'Gross_Sales_USD', 'Marketing_Spend_USD', 'COGS_USD',
#        'Logistics_Cost_USD', 'Net_Revenue_USD', 'Profit_USD',
#        'Profit_Margin_Pct'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Order_ID               0
# Order_Date             0
# Year                   0
# Quarter                0
# Month                  0
# Month_Name             0
# Region                 0
# Country                0
# City                   0
# Sales_Person           0
# Customer_Type          0
# Sales_Channel          0
# Promotion_Type         0
# Product_Category       0
# Brand                  0
# Product_Name           0
# SKU                    0
# Units_Sold             0
# Unit_Price_USD         0
# Discount_Pct           0
# Gross_Sales_USD        0
# Marketing_Spend_USD    0
# COGS_USD               0
# Logistics_Cost_USD     0
# Net_Revenue_USD        0
# Profit_USD             0
# Profit_Margin_Pct      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#            Order_ID  Order_Date  Year Quarter  Month Month_Name  \
# 0  FMCG-2025-000001  2025-09-26  2025      Q3      9  September
# 1  FMCG-2024-000002  2024-10-09  2024      Q4     10    October
# 2  FMCG-2024-000003  2024-07-06  2024      Q3      7       July
# 3  FMCG-2024-000004  2024-05-25  2024      Q2      5        May
# 4  FMCG-2023-000005  2023-08-10  2023      Q3      8     August
#
#           Region    Country         City   Sales_Person  ... Units_Sold  \
# 0        Oceania  Australia        Perth     Ethan Cole  ...         73
# 1           Asia      India       Mumbai     Meera Nair  ...         99
# 2  North America        USA  Los Angeles    Nina Booker  ...        361
# 3         Europe     France        Paris    Oliver Kent  ...        603
# 4         Europe     France         Lyon  Lucas Bennett  ...        113
#
#   Unit_Price_USD Discount_Pct Gross_Sales_USD Marketing_Spend_USD COGS_USD  \
# 0           8.47         8.94          618.31               66.05   314.09
# 1           2.89         9.86          286.11               35.26   123.79
# 2           5.96        15.32         2151.56              171.46  1011.60
# 3           3.80        18.00         2291.40              118.39  1133.66
# 4           3.18        12.46          359.34               34.82   157.70
#
#   Logistics_Cost_USD  Net_Revenue_USD  Profit_USD  Profit_Margin_Pct
# 0              43.03           563.03      139.86              24.84
# 1              23.89           257.90       74.96              29.07
# 2             107.02          1821.94      531.86              29.19
# 3              85.20          1878.95      541.70              28.83
# 4              23.02           314.57       99.03              31.48
#
# [5 rows x 27 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18240 entries, 0 to 18239
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order_ID             18240 non-null  object
#  1   Order_Date           18240 non-null  object
#  2   Year                 18240 non-null  int64
#  3   Quarter              18240 non-null  object
#  4   Month                18240 non-null  int64
#  5   Month_Name           18240 non-null  object
#  6   Region               18240 non-null  object
#  7   Country              18240 non-null  object
#  8   City                 18240 non-null  object
#  9   Sales_Person         18240 non-null  object
#  10  Customer_Type        18240 non-null  object
#  11  Sales_Channel        18240 non-null  object
#  12  Promotion_Type       18240 non-null  object
#  13  Product_Category     18240 non-null  object
#  14  Brand                18240 non-null  object
#  15  Product_Name         18240 non-null  object
#  16  SKU                  18240 non-null  object
#  17  Units_Sold           18240 non-null  int64
#  18  Unit_Price_USD       18240 non-null  float64
#  19  Discount_Pct         18240 non-null  float64
#  20  Gross_Sales_USD      18240 non-null  float64
#  21  Marketing_Spend_USD  18240 non-null  float64
#  22  COGS_USD             18240 non-null  float64
#  23  Logistics_Cost_USD   18240 non-null  float64
#  24  Net_Revenue_USD      18240 non-null  float64
#  25  Profit_USD           18240 non-null  float64
#  26  Profit_Margin_Pct    18240 non-null  float64
# dtypes: float64(9), int64(3), object(15)
# memory usage: 3.8+ MB

# %%
data.drop(columns=['SKU'],inplace=True)

# %%
data.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Year', 'Quarter', 'Month', 'Month_Name',
#        'Region', 'Country', 'City', 'Sales_Person', 'Customer_Type',
#        'Sales_Channel', 'Promotion_Type', 'Product_Category', 'Brand',
#        'Product_Name', 'Units_Sold', 'Unit_Price_USD', 'Discount_Pct',
#        'Gross_Sales_USD', 'Marketing_Spend_USD', 'COGS_USD',
#        'Logistics_Cost_USD', 'Net_Revenue_USD', 'Profit_USD',
#        'Profit_Margin_Pct'],
#       dtype='object')

# %%
data.shape
# Out:
# (18240, 26)

# %%
data
# Out:
#                Order_ID  Order_Date  Year Quarter  Month Month_Name  \
# 0      FMCG-2025-000001  2025-09-26  2025      Q3      9  September
# 1      FMCG-2024-000002  2024-10-09  2024      Q4     10    October
# 2      FMCG-2024-000003  2024-07-06  2024      Q3      7       July
# 3      FMCG-2024-000004  2024-05-25  2024      Q2      5        May
# 4      FMCG-2023-000005  2023-08-10  2023      Q3      8     August
# ...                 ...         ...   ...     ...    ...        ...
# 18235  FMCG-2023-018236  2023-01-19  2023      Q1      1    January
# 18236  FMCG-2023-018237  2023-06-22  2023      Q2      6       June
# 18237  FMCG-2025-018238  2025-10-30  2025      Q4     10    October
# 18238  FMCG-2023-018239  2023-12-25  2023      Q4     12   December
# 18239  FMCG-2024-018240  2024-06-20  2024      Q2      6       June
#
#               Region    Country            City   Sales_Person  ...  \
# 0            Oceania  Australia           Perth     Ethan Cole  ...
# 1               Asia      India          Mumbai     Meera Nair  ...
# 2      North America        USA     Los Angeles    Nina Booker  ...
# 3             Europe     France           Paris    Oliver Kent  ...
# 4             Europe     France            Lyon  Lucas Bennett  ...
# ...              ...        ...             ...            ...  ...
# 18235           Asia  Indonesia         Jakarta    Anika Verma  ...
# 18236         Europe      Spain          Madrid   Elena Dupont  ...
# 18237         Europe     France           Paris  Marco Bellini  ...
# 18238  South America     Brazil  Rio de Janeiro  Lucia Herrera  ...
# 18239         Europe    Germany         Hamburg  Marco Bellini  ...
#
#       Units_Sold Unit_Price_USD Discount_Pct Gross_Sales_USD  \
# 0             73           8.47         8.94          618.31
# 1             99           2.89         9.86          286.11
# 2            361           5.96        15.32         2151.56
# 3            603           3.80        18.00         2291.40
# 4            113           3.18        12.46          359.34
# ...          ...            ...          ...             ...
# 18235         39           7.87        13.68          306.93
# 18236         53           6.06        13.93          321.18
# 18237        143           3.43        13.21          490.49
# 18238        237           6.02        13.82         1426.74
# 18239         83           3.42         6.07          283.86
#
#       Marketing_Spend_USD COGS_USD  Logistics_Cost_USD  Net_Revenue_USD  \
# 0                   66.05   314.09               43.03           563.03
# 1                   35.26   123.79               23.89           257.90
# 2                  171.46  1011.60              107.02          1821.94
# 3                  118.39  1133.66               85.20          1878.95
# 4                   34.82   157.70               23.02           314.57
# ...                   ...      ...                 ...              ...
# 18235               41.32   149.17               31.24           264.94
# 18236               35.42   155.27               21.25           276.44
# 18237               72.35   314.69               36.50           425.70
# 18238              124.61   713.18               92.59          1229.56
# 18239               43.66   184.79               32.67           266.63
#
#        Profit_USD  Profit_Margin_Pct
# 0          139.86              24.84
# 1           74.96              29.07
# 2          531.86              29.19
# 3          541.70              28.83
# 4           99.03              31.48
# ...           ...                ...
# 18235       43.21              16.31
# 18236       64.50              23.33
# 18237        2.16               0.51
# 18238      299.18              24.33
# 18239        5.51               2.07
#
# [18240 rows x 26 columns]

# %%
data.describe().round()
# Out:
#           Year    Month  Units_Sold  Unit_Price_USD  Discount_Pct  \
# count  18240.0  18240.0     18240.0         18240.0       18240.0
# mean    2024.0      7.0       213.0             4.0          13.0
# std        1.0      3.0       202.0             2.0           6.0
# min     2023.0      1.0         5.0             1.0           0.0
# 25%     2023.0      3.0        70.0             3.0           9.0
# 50%     2024.0      7.0       139.0             4.0          13.0
# 75%     2025.0     10.0       288.0             5.0          17.0
# max     2025.0     12.0      1366.0            13.0          28.0
#
#        Gross_Sales_USD  Marketing_Spend_USD  COGS_USD  Logistics_Cost_USD  \
# count          18240.0              18240.0   18240.0             18240.0
# mean             936.0                 86.0     471.0                54.0
# std             1046.0                 88.0     537.0                51.0
# min               13.0                  2.0       6.0                 1.0
# 25%              275.0                 33.0     141.0                21.0
# 50%              565.0                 61.0     287.0                39.0
# 75%             1214.0                108.0     600.0                69.0
# max            10634.0               1768.0    6473.0               629.0
#
#        Net_Revenue_USD  Profit_USD  Profit_Margin_Pct
# count          18240.0     18240.0            18240.0
# mean             792.0       181.0               20.0
# std              861.0       240.0               11.0
# min               11.0      -638.0              -45.0
# 25%              245.0        32.0               14.0
# 50%              494.0        92.0               21.0
# 75%             1027.0       239.0               27.0
# max             8753.0      2723.0               44.0

# %%
pd.set_option('display.max_columns', None)
data.head()
# Out:
#            Order_ID  Order_Date  Year Quarter  Month Month_Name  \
# 0  FMCG-2025-000001  2025-09-26  2025      Q3      9  September
# 1  FMCG-2024-000002  2024-10-09  2024      Q4     10    October
# 2  FMCG-2024-000003  2024-07-06  2024      Q3      7       July
# 3  FMCG-2024-000004  2024-05-25  2024      Q2      5        May
# 4  FMCG-2023-000005  2023-08-10  2023      Q3      8     August
#
#           Region    Country         City   Sales_Person Customer_Type  \
# 0        Oceania  Australia        Perth     Ethan Cole           B2C
# 1           Asia      India       Mumbai     Meera Nair           B2C
# 2  North America        USA  Los Angeles    Nina Booker           B2B
# 3         Europe     France        Paris    Oliver Kent           B2B
# 4         Europe     France         Lyon  Lucas Bennett           B2C
#
#   Sales_Channel     Promotion_Type   Product_Category        Brand  \
# 0  Modern Trade  Seasonal Campaign      Personal Care     PureLiva
# 1        Online       Bundle Offer      Personal Care  BrightSmile
# 2   Distributor  Seasonal Campaign      Personal Care    FreshNest
# 3     Wholesale           No Promo             Snacks    NutriBite
# 4  Modern Trade   Loyalty Cashback  Dairy & Breakfast      FarmJoy
#
#          Product_Name  Units_Sold  Unit_Price_USD  Discount_Pct  \
# 0      Shampoo Repair          73            8.47          8.94
# 1     Toothpaste Mint          99            2.89          9.86
# 2    Body Wash Citrus         361            5.96         15.32
# 3  Protein Bar Peanut         603            3.80         18.00
# 4  Greek Yogurt Plain         113            3.18         12.46
#
#    Gross_Sales_USD  Marketing_Spend_USD  COGS_USD  Logistics_Cost_USD  \
# 0           618.31                66.05    314.09               43.03
# 1           286.11                35.26    123.79               23.89
# 2          2151.56               171.46   1011.60              107.02
# 3          2291.40               118.39   1133.66               85.20
# 4           359.34                34.82    157.70               23.02
#
#    Net_Revenue_USD  Profit_USD  Profit_Margin_Pct
# 0           563.03      139.86              24.84
# 1           257.90       74.96              29.07
# 2          1821.94      531.86              29.19
# 3          1878.95      541.70              28.83
# 4           314.57       99.03              31.48

# %%
data.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18240 entries, 0 to 18239
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order_ID             18240 non-null  object
#  1   Order_Date           18240 non-null  object
#  2   Year                 18240 non-null  int64
#  3   Quarter              18240 non-null  object
#  4   Month                18240 non-null  int64
#  5   Month_Name           18240 non-null  object
#  6   Region               18240 non-null  object
#  7   Country              18240 non-null  object
#  8   City                 18240 non-null  object
#  9   Sales_Person         18240 non-null  object
#  10  Customer_Type        18240 non-null  object
#  11  Sales_Channel        18240 non-null  object
#  12  Promotion_Type       18240 non-null  object
#  13  Product_Category     18240 non-null  object
#  14  Brand                18240 non-null  object
#  15  Product_Name         18240 non-null  object
#  16  Units_Sold           18240 non-null  int64
#  17  Unit_Price_USD       18240 non-null  float64
#  18  Discount_Pct         18240 non-null  float64
#  19  Gross_Sales_USD      18240 non-null  float64
#  20  Marketing_Spend_USD  18240 non-null  float64
#  21  COGS_USD             18240 non-null  float64
#  22  Logistics_Cost_USD   18240 non-null  float64
#  23  Net_Revenue_USD      18240 non-null  float64
#  24  Profit_USD           18240 non-null  float64
#  25  Profit_Margin_Pct    18240 non-null  float64
# dtypes: float64(9), int64(3), object(14)
# memory usage: 3.6+ MB

# %%
print(data.dtypes)
# Out:
# Order_ID                object
# Order_Date              object
# Year                     int64
# Quarter                 object
# Month                    int64
# Month_Name              object
# Region                  object
# Country                 object
# City                    object
# Sales_Person            object
# Customer_Type           object
# Sales_Channel           object
# Promotion_Type          object
# Product_Category        object
# Brand                   object
# Product_Name            object
# Units_Sold               int64
# Unit_Price_USD         float64
# Discount_Pct           float64
# Gross_Sales_USD        float64
# Marketing_Spend_USD    float64
# COGS_USD               float64
# Logistics_Cost_USD     float64
# Net_Revenue_USD        float64
# Profit_USD             float64
# Profit_Margin_Pct      float64
# dtype: object

# %%
print(data.describe().round(2))
# Out:
#            Year     Month  Units_Sold  Unit_Price_USD  Discount_Pct  \
# count  18240.00  18240.00    18240.00        18240.00      18240.00
# mean    2024.00      6.52      212.91            4.47         12.94
# std        0.82      3.47      202.10            1.95          5.74
# min     2023.00      1.00        5.00            1.45          0.00
# 25%     2023.00      3.00       70.00            3.02          8.71
# 50%     2024.00      7.00      139.00            3.99         12.69
# 75%     2025.00     10.00      288.00            5.44         16.85
# max     2025.00     12.00     1366.00           12.74         28.00
#
#        Gross_Sales_USD  Marketing_Spend_USD  COGS_USD  Logistics_Cost_USD  \
# count         18240.00             18240.00  18240.00            18240.00
# mean            936.43                85.74    471.02               54.03
# std            1045.61                87.55    537.35               51.27
# min              13.02                 1.81      6.31                1.08
# 25%             274.53                33.49    140.51               21.37
# 50%             565.43                61.39    287.16               38.98
# 75%            1213.84               107.60    599.79               69.24
# max           10634.12              1767.71   6473.33              628.86
#
#        Net_Revenue_USD  Profit_USD  Profit_Margin_Pct
# count         18240.00    18240.00           18240.00
# mean            792.21      181.41              19.87
# std             861.24      239.53              10.57
# min              10.54     -637.50             -45.31
# 25%             245.22       32.34              13.72
# 50%             493.90       91.89              20.87
# 75%            1027.36      239.12              27.26
# max            8752.94     2723.00              44.49

# %%
cols = [
    'Year', 'Month', 'Month_Name',
    'Region', 'Country', 'City',
    'Sales_Person', 'Customer_Type',
    'Sales_Channel', 'Promotion_Type',
    'Product_Category', 'Brand',
    'Product_Name'
]

for col in cols:
    print(f"\nUnique values in {col}:")
    print(data[col].unique())
# Out:
# Unique values in Year:
# [2025 2024 2023]
#
# Unique values in Month:
# [ 9 10  7  5  8  3  1 12  2  6  4 11]
#
# Unique values in Month_Name:
# ['September' 'October' 'July' 'May' 'August' 'March' 'January' 'December'
#  'February' 'June' 'April' 'November']
#
# Unique values in Region:
# ['Oceania' 'Asia' 'North America' 'Europe' 'South America']
#
# Unique values in Country:
# ['Australia' 'India' 'USA' 'France' 'Thailand' 'UK' 'Italy' 'Colombia'
#  'Chile' 'Brazil' 'Spain' 'Mexico' 'Germany' 'Indonesia' 'Canada'
#  'New Zealand' 'UAE']
#
# Unique values in City:
# ['Perth' 'Mumbai' 'Los Angeles' 'Paris' 'Lyon' 'Bangkok' 'Hyderabad'
#  'Manchester' 'Milan' 'Medellin' 'London' 'Valparaiso' 'Sao Paulo'
#  'Madrid' 'Guadalajara' 'Hamburg' 'Delhi' 'Jakarta' 'Bengaluru'
#  'Mexico City' 'Surabaya' 'Atlanta' 'Berlin' 'Vancouver' 'Rio de Janeiro'
#  'Wellington' 'Melbourne' 'New York' 'Munich' 'Marseille' 'Sydney'
#  'Bogota' 'Abu Dhabi' 'Dubai' 'Brisbane' 'Birmingham' 'Monterrey' 'Dallas'
#  'Santiago' 'Montreal' 'Barcelona' 'Valencia' 'Turin' 'Chiang Mai' 'Rome'
#  'Auckland' 'Toronto' 'Chicago']
#
# Unique values in Sales_Person:
# ['Ethan Cole' 'Meera Nair' 'Nina Booker' 'Oliver Kent' 'Lucas Bennett'
#  'Nikhil Bhat' 'Farah Siddiqui' 'Marco Bellini' 'Elena Dupont'
#  'Lucia Herrera' 'Mateo Silva' 'Hugo Martin' 'Rohan Iyer' 'Aarav Malhotra'
#  'Javier Morales' 'Rizwan Khan' 'Diya Kapoor' 'Sharon Patel'
#  'Andres Castillo' 'Sofia Mercer' 'Charlotte Ellis' 'Lena Crawford'
#  'Valentina Rojas' 'Noah Sinclair' 'Mia Sutton' 'Amelia Rhodes'
#  'Talia Whitmore' 'Camila Torres' 'Colin Reese' 'Derek Boone'
#  'Anika Verma' 'Logan Price' 'Bruno Carvalho' 'Sienna Hart' 'Marcus Doyle'
#  'Harper Lawson']
#
# Unique values in Customer_Type:
# ['B2C' 'B2B']
#
# Unique values in Sales_Channel:
# ['Modern Trade' 'Online' 'Distributor' 'Wholesale']
#
# Unique values in Promotion_Type:
# ['Seasonal Campaign' 'Bundle Offer' 'No Promo' 'Loyalty Cashback'
#  'Introductory Offer' 'Flash Discount' 'Festival Campaign']
#
# Unique values in Product_Category:
# ['Personal Care' 'Snacks' 'Dairy & Breakfast' 'Household' 'Beverages']
#
# Unique values in Brand:
# ['PureLiva' 'BrightSmile' 'FreshNest' 'NutriBite' 'FarmJoy' 'Softora'
#  'FuelCore' 'SparkShield' 'CrunchMile' 'AquaGlow' 'PantryPeak'
#  'RoastTrail' 'TrailNest' 'ZenLeaf' 'MorningCo' 'HomeNest' 'Biscora']
#
# Unique values in Product_Name:
# ['Shampoo Repair' 'Toothpaste Mint' 'Body Wash Citrus'
#  'Protein Bar Peanut' 'Greek Yogurt Plain' 'Paper Towels'
#  'Energy Drink Classic' 'Glass Cleaner' 'Potato Chips BBQ'
#  'Sparkling Water Lemon' 'Energy Drink Zero' 'Sparkling Water Berry'
#  'Conditioner Smooth' 'Peanut Butter Creamy' 'Instant Coffee Gold'
#  'Protein Bar Cocoa' 'Hand Soap Gentle' 'Yogurt Cup Strawberry'
#  'Trail Mix Original' 'Green Tea Bags' 'Oats Wholegrain'
#  'Laundry Detergent' 'Granola Honey' 'Chocolate Cookies'
#  'Potato Chips Sea Salt' 'Toothbrush Soft' 'Surface Cleaner'
#  'Dishwash Liquid' 'Tissue Pack' 'Cereal Corn Flakes']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols = [
    'Units_Sold',
    'Gross_Sales_USD',
    'Marketing_Spend_USD',
    'COGS_USD',
    'Logistics_Cost_USD',
    'Net_Revenue_USD',
    'Profit_USD'
]

plt.figure(figsize=(18,10))

for i, col in enumerate(cols,1):

    plt.subplot(3,3,i)

    sns.boxplot(y=data[col])

    plt.title(col)

plt.tight_layout()
plt.show()

# %%
numeric_cols = data.select_dtypes(include=['int64','float64']).columns

print(data[numeric_cols].skew().sort_values(ascending=False))
# Out:
# Marketing_Spend_USD    4.007235
# COGS_USD               3.043265
# Logistics_Cost_USD     2.785265
# Profit_USD             2.730585
# Gross_Sales_USD        2.656103
# Net_Revenue_USD        2.647228
# Units_Sold             1.583386
# Unit_Price_USD         1.227104
# Discount_Pct           0.209506
# Year                  -0.002922
# Month                 -0.009537
# Profit_Margin_Pct     -0.720501
# dtype: float64

# %%
import boto3
from botocore.exceptions import NoCredentialsError, ClientError
import os

# %%
def upload_to_s3(local_file, bucket, s3_file):

    print("Creating S3 client...")

    s3 = boto3.client(
        's3',
        aws_access_key_id='ACCESS_KEY',
        aws_secret_access_key='SECRET_KEY',
        region_name='ap-south-1'
    )

    print("S3 client created")

    try:

        print("Current Folder:", os.getcwd())

        print("Checking if file exists...")
        print(os.path.exists(local_file))

        print("Starting upload...")

        s3.upload_file(local_file, bucket, s3_file)

        print("Upload Successful")
        return True

    except FileNotFoundError:
        print("The file was not found")

    except NoCredentialsError:
        print("Credentials not available")

    except ClientError as e:
        print("AWS Client Error:")
        print(e)

    except Exception as e:
        print("General Error:")
        print(e)

    return False


upload_to_s3(
    'fmcg_sales_marketing_profitability_2023_2025.csv',
    'fmcg-project-2026',
    'data/uploaded_file.csv'
)
# Out:
# Creating S3 client...
# S3 client created
# Current Folder: c:\Users\shree\Desktop\projects\python\fmcg_data_analysis
# Checking if file exists...
# True
# Starting upload...
# Upload Successful
# True
